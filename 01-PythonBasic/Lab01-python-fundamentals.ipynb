# %% [markdown]
# # Python Fundamentals for Scientific Computing
#
# A hands-on introduction to Python for engineering and science students.
#
# ## Learning Objectives
#
# By the end of this session, you will be able to:
# - Assign and inspect variables of different Python types (scalars, complex numbers, arrays)
# - Perform mathematical and matrix operations using **NumPy**
# - Use Python's built-in and library functions effectively
# - Create publication-quality plots with **Matplotlib**
#
# ## Session Outline
#
# | # | Topic |
# |---|-------|
# | 1 | Variables & Assignment |
# | 2 | NumPy Arrays & Matrices |
# | 3 | Mathematical Operations |
# | 4 | Built-in Functions |
# | 5 | Visualization with Matplotlib |
# | 6 | Wrap-up & Q&A |
#
# ## Key Libraries

# %%
import numpy as np            # N-dimensional arrays & linear algebra
import matplotlib.pyplot as plt   # data visualization
import math                   # standard math functions
import scipy.constants as pc      # physical constants (e.g., Planck's h)

# %% [markdown]
# ---
# ## 1. Variables & Assignment
#
# In Python, **assignment** binds a name to a value using `=`.
#
# ```python
# x = 42        # int   — whole numbers
# y = 3.14      # float — real numbers (64-bit by default)
# z = 2 + 4j    # complex — real + imaginary part
# ```
#
# Key points:
# - Python is **dynamically typed** — no type declarations needed; the interpreter infers the type
# - Use `type()` to inspect any variable's type at runtime
# - Variable names are **case-sensitive**: `Voltage` ≠ `voltage`
# - Multiple assignments on one line: `a = b = 0` or `x, y = 1, 2`

# %%
# scalars
a = 4
print(type(a))

# %%
# complex number
c = 2 + 4j
print(c)
print(type(c))

# %%
import math

print(math.pi)
print(math.e)

# %%
# format display
print('{0:7.4f}'.format(math.pi))
print(math.pi)

print(type('{0:7.4f}'.format(math.pi)))
print(type(math.pi))

# %% [markdown]
# > **Tip — Variable Inspector:** In JupyterLab, open the *Jupyter* tab (or install `jupyterlab-variableinspector`) to see a live table of all variables: their names, types, sizes, and current values. This is handy for debugging without scattering `print()` calls everywhere.

# %%
# Format Planck's constant, h
import scipy.constants as pc
print(pc.h)
print('{0:12.4e}'.format(pc.h))

# %% [markdown]
# ---
# ## 2. NumPy Arrays, Vectors & Matrices
#
# **NumPy** (`numpy`) is the foundation of scientific computing in Python. Its core object is the `ndarray` — an N-dimensional array stored in contiguous memory.
#
# Why use NumPy instead of Python lists?
# - **Speed:** operations are implemented in C — 10–100× faster than loops
# - **Vectorization:** apply math to entire arrays without writing loops
# - **Broadcasting:** operations on arrays of different shapes work intuitively
#
# ### Creating arrays
#
# | Function | Description |
# |----------|-------------|
# | `np.array([...])` | From a Python list |
# | `np.zeros((m, n))` | All zeros, shape m × n |
# | `np.ones((m, n))` | All ones |
# | `np.eye(n)` | Identity matrix n × n |
# | `np.arange(start, stop, step)` | Evenly spaced (like Python `range`) |
# | `np.linspace(start, stop, n)` | *n* evenly spaced points (inclusive) |
# | `np.logspace(start, stop, n)` | *n* points on a log scale |
#
# > **Note on `np.matrix`:** The `np.matrix` class is **deprecated** since NumPy 1.25 and will be removed in a future release. Use `np.array` for all data and the `@` operator for matrix multiplication.

# %%
# Arrays, Vectors, and Matrices

# one-dimensional array x
import numpy as np
x = np.array([12.2, 10.9, 13.6, 8.4, 11.1])

print(x)

# %%
# a two-dimenisonal array 
A = np.array([[2,4],[1,3]])
print(A)

# %%
# A matrix
A = np.matrix('2 4; 1 3')
print(A)
print(A.shape)

# %%
x = np.matrix('12.2 10.9 13.6 8.4 11.1 ')
print(x)
print(x.shape)

# %%
np.squeeze(np.array(x))

# %%
w = np.matrix( '12.2 ; 10.9; 13.6; 8.4; 11.1')
print(w)
print(w.shape)

# %%
# first row, second column 
w[0,1]

# %%
# second row, first column
w[1,0]

# %%
Z = np.zeros((5,3))
print(Z)

# %%
# convert to an array to a matrix
Zm = np.matrix(Z)
print(Zm)

# %%
# Built-in function 'ones' 
B = np.ones((2,3))
print(B)

# %%
# Built-in function 'eye' 
C = np.eye(3)
print(C)

# %%
# Subscript 
print(A)

# first row, all columns
A[0,:]

# all rows, second column
A[:,1]

# %%
# Subscript ranges
print(x)

# the result does NOT include the upper limit
print(x[0,0:2])
print(x[0,0:])
print(x[0,0:-1])
print(x[0,0:-2])

# %%
# arange

x = np.arange(0,1)
print(x)

# NOTE that the last number is NOT included.
x = np.arange(0,1,0.1)
print(x)

# %%
# linspace 
x = np.linspace(0,1,11)
print(x)

x = np.linspace(0,1,10,endpoint=False)
print(x)

# %% [markdown]
# ### Strings
#
# In Python, strings are **immutable** sequences of characters, enclosed in `'single'` or `"double"` quotes.
#
# ```python
# s = 'Hello'
# s[0]        # → 'H'   (indexing)
# s[1:3]      # → 'el'  (slicing — same rules as arrays)
# s + ' World'  # → 'Hello World'  (concatenation)
# s.upper()   # → 'HELLO'
# len(s)      # → 5
# ```
#
# Useful escape sequences: `\n` (newline), `\t` (tab), `\\` (literal backslash).

# %%
# logspace
x = np.logspace(-1,2,4)
print(x)


x = np.logspace(1,6,6, base=2.0)
print(x)

# %%
# Character strings
f = 'Alison'
s = 'Krauss'

print(f[3])
print(s[2])

# %%
# concatenate strings 
f + s

# %% [markdown]
# ### Lists
#
# Python **lists** are ordered, mutable sequences that can hold items of **mixed types**.
#
# ```python
# a = [1, 2.5, 'hello', True]   # mixed types — unlike NumPy arrays
# a[0]          # → 1          (0-indexed)
# a[-1]         # → True       (negative index counts from the end)
# a.append(42)  # adds 42 to the end (in-place)
# len(a)        # → 5
# ```
#
# Use lists when you need a general-purpose container. Use NumPy arrays when you need fast numerical computation.
#
# > **Line continuation:** Long expressions can be broken across lines using `\` or by wrapping in parentheses `( )`, brackets `[ ]`, or braces `{ }`.

# %%
f + ' ' + s

# %%
# break line
a = [1,2,3,4, 5, \
    6, 7, 8 ]
print(a)

# %%
len(a)

# %%
float('3.14')

# %%
'abc'.upper()

# %%
print('Washington \n Adams \n Jefferson \n Madison')

# %% [markdown]
# ---
# ## 3. Mathematical Operations
#
# Python supports standard arithmetic operators:
#
# | Operator | Meaning | Example |
# |----------|---------|---------|
# | `+` | Addition | `3 + 2` → `5` |
# | `-` | Subtraction / Negation | `3 - 2` → `1` |
# | `*` | Multiplication | `3 * 2` → `6` |
# | `/` | Division (float result) | `7 / 2` → `3.5` |
# | `//` | Integer (floor) division | `7 // 2` → `3` |
# | `%` | Modulus (remainder) | `7 % 2` → `1` |
# | `**` | Exponentiation | `2 ** 3` → `8` |
# | `@` | Matrix multiplication (NumPy) | `A @ B` |
#
# **Operator precedence** follows the usual mathematical convention (PEMDAS), and is evaluated **left to right** within the same level — except `**`, which is **right to left**.
#
# ```python
# 3 ** 2 ** 2   # → 3 ** (2 ** 2) = 3 ** 4 = 81  (right-to-left)
# ```

# %%
import numpy as np 

np.pi * 0.5**2 / 4

# %%
x = 3; y = 2; z=1.5

print(x ** y ** z) #right to left
print(y ** z)
print(x ** (y ** z)) 
print(( x ** y) ** z)

# %%
y ** z

# %%
# Calculations can involve complex quantities.
a = 2 + 4j
b = 0.5 - 0.3j

print(1/a)
print(a*b)
print(a**2)
print(a/b)

# %%
# vector dot
a = np.matrix(' 1 2 3 4 5')
b = np.matrix('2; 4; 6; 8; 10')
print(a)
print(b)
print(a*b)

# %%
# matrix vector product 
A = np.matrix('1. 2. 3. ; 4. 5. 6.; 7. 8. 9.')
print('A=',A)
b = np.matrix('1. 2. 3.')
c = np.matrix('4.;  5.; 6.')
print('b=',b)
print('c=',c)

print(b*A)
print(A*c)

# %%
# transpose of A

A.transpose()

# %%
# matrix multiplication
print(A * A)
print(A ** 2)

# %%
# elementwise operation
print(np.multiply(A,A))

# %%
# Note that using * with arrays performs element-wise multiplication!

a = np.array([1., 2., 3.])
b = np.array([4., 5., 6.])

print(a*b)

# %%
# inner product requires dot 
print(a.dot(b))

# cross product requires cross
print(np.cross(a,b))

# %% [markdown]
# ---
# ## 4. Built-in Functions
#
# Python provides many useful built-in functions without any import:
#
# | Function | Description | Example |
# |----------|-------------|---------|
# | `abs(x)` | Absolute value (or modulus for complex) | `abs(-3)` → `3` |
# | `round(x, n)` | Round to *n* decimal places | `round(3.14159, 2)` → `3.14` |
# | `min(...)` / `max(...)` | Minimum / Maximum | `min(2, 5, 1)` → `1` |
# | `len(x)` | Length of a sequence | `len([1,2,3])` → `3` |
# | `type(x)` | Type of an object | `type(3.14)` → `float` |
# | `float(x)` | Convert to float | `float('3.14')` → `3.14` |
# | `int(x)` | Convert to integer | `int(3.7)` → `3` |
#
# For math functions not built-in (e.g., `sqrt`, `log`, `sin`), use the `math` module or NumPy.
# Use `help(function)` anytime to read the documentation inline.

# %%
import math

help(math.log)

# %%
abs(-6 + 4j)

# %% [markdown]
# ### Application: Bungee Jumper Velocity
#
# A classic numerical methods problem: the **analytical solution** for the velocity of a free-falling bungee jumper with linear drag is:
#
# $$v(t) = \sqrt{\frac{mg}{c_d}} \tanh\!\left(\sqrt{\frac{c_d g}{m}}\, t\right)$$
#
# Where:
# - $m = 68.1$ kg (mass of jumper)
# - $g = 9.81$ m/s² (gravity)
# - $c_d = 0.25$ kg/m (drag coefficient)
# - $t$ = time vector (seconds)
#
# NumPy's **vectorization** lets us evaluate this formula for all time values at once — no loop needed.

# %%
print(round(4.5))
print(round(4.51))

# %%
x = 14; y = 22
max(x,y)

# %%
a = np.array([2,7,3,-4, 3.5])

print(min(a))
print(max(a))

# %%
# vector operation
tm = np.linspace(0,20, 11)
print(tm)

g = 9.81
m = 68.1
cd = 0.25

v = math.sqrt(m*g/cd)*np.tanh(math.sqrt(cd*g/m)*tm)
print(v)
print(type(v))

# %%
# matrix also support vectorization

tmm = np.matrix(tm)

vm = math.sqrt(m*g/cd)*np.tanh(math.sqrt(cd*g/m)*tmm)
print(vm)
print(type(vm))

tmmt = tmm.transpose()

# %% [markdown]
# ---
# ## 5. Visualization with Matplotlib
#
# **Matplotlib** is the standard plotting library in Python. The `pyplot` submodule provides a MATLAB-like interface.
#
# ```python
# import matplotlib.pyplot as plt
#
# plt.plot(x, y)          # line plot
# plt.scatter(x, y)       # scatter plot
# plt.xlabel('...')       # x-axis label
# plt.ylabel('...')       # y-axis label
# plt.title('...')        # plot title
# plt.legend()            # show legend (requires label= in plot calls)
# plt.grid()              # add grid lines
# plt.savefig('out.png')  # save to file
# plt.show()              # display (not needed in Jupyter)
# ```
#
# We will use the **bungee jumper** velocity as our dataset — a classic problem in numerical methods.

# %%
x = tm
y = v

print(x)
print(y)
print(len(x))
print(len(y))

# %%
import matplotlib.pyplot as plt

# Plot
plt.plot(x,y)

# %%
# you can customize your plot
plt.plot(x,y)
plt.title('Velocity of Bungee Jumper versus Time')
plt.xlabel('Time in seconds')
plt.ylabel('Velocity in m/s')
plt.grid()

# %%
plt.scatter(x,y)

# %% [markdown]
# ### Bonus: Python Sets
#
# A **set** is an unordered collection of **unique** elements. Python automatically removes duplicates.
#
# ```python
# s = {1, 2, 2, 3}   # → {1, 2, 3}
# ```
#
# Sets are useful for membership testing, deduplication, and set operations (union, intersection, difference). Notice that `True` and `1` are treated as equal in a set.

# %%
# you can add markers to the plot
plt.plot(x,y,marker='o')

# %%
# change the line style and its color
plt.plot(x,y,ls='--',c='k',marker='D')

# %% [markdown]
# ---
# ## Summary
#
# Today we covered the Python essentials for scientific computing:
#
# | Topic | Key Concepts / Functions |
# |-------|--------------------------|
# | **Variables** | `int`, `float`, `complex`, `str`, `list`; `type()` |
# | **Formatting** | `'{0:.4f}'.format(x)`, `f'{x:.4f}'` |
# | **NumPy Arrays** | `np.array()`, `.shape`, indexing `a[i, j]`, slicing `a[1:3]` |
# | **Array creation** | `np.zeros()`, `np.ones()`, `np.eye()` |
# | **Ranges** | `np.arange()`, `np.linspace()`, `np.logspace()` |
# | **Math Ops** | `+`, `-`, `*`, `/`, `**`; `@` for matrix mult; `np.dot()`, `np.cross()` |
# | **Built-ins** | `abs()`, `round()`, `min()`, `max()`, `len()`, `math.sqrt()` |
# | **Plotting** | `plt.plot()`, `plt.scatter()`, labels, legend, grid, `plt.savefig()` |
# | **Memory** | View (slicing, shared memory) vs. Copy (indexing, independent) |
#
# ## What's Next?
#
# - **Practice:** Recreate the bungee jumper plot with $m = 80$ kg and $c_d \in \{0.2, 0.25, 0.3\}$ on the same figure
# - **Explore:** [NumPy documentation](https://numpy.org/doc/) · [Matplotlib gallery](https://matplotlib.org/stable/gallery/)
# - **Next lecture:** Control flow (`if`, `for`, `while`) and writing your own functions

# %%
# you can plot two curves on a graph
cd = 0.25
v1 = math.sqrt(m*g/cd)*np.tanh(math.sqrt(cd*g/m)*tm)
cd = 0.3
v2 = math.sqrt(m*g/cd)*np.tanh(math.sqrt(cd*g/m)*tm)

plt.plot(x,v1,ls='-',c='k',marker='D',label='cd=0.25')
plt.plot(x,v2,ls='--',c='b',marker='o',label='cd=0.30')
plt.xlabel('Time in seconds')
plt.ylabel('Velocity in m/s')
plt.legend(loc='lower right')
plt.grid()

# save a plot
plt.savefig('sample.png', bbox_inches='tight')

# %%
thisset = {"apple", "banana", "cherry", True, 1, 2}
print(thisset)

# %% [markdown]
# ---
# ## 6. Views vs. Copies in NumPy
#
# This is one of the most common sources of bugs in NumPy code.
#
# | | View | Copy |
# |--|------|------|
# | How | Slicing: `y = x[1:3]` | Fancy indexing: `y = x[[1,2]]` or `x.copy()` |
# | Memory | Shares data with original | Independent memory |
# | Effect | Modifying `x` changes `y` | `x` and `y` are independent |
# | Check | `y.base is not None` | `y.base is None` |
#
# **Rule of thumb:**
# - Basic slicing (`[start:stop:step]`) → **view**
# - Integer array indexing, boolean indexing → **copy**
#
# When in doubt, use `.copy()` to guarantee independence.

# %%
import numpy as np

x = np.arange(10)
print(x)
y = x[1:3]  # creates a view
print(y)
x[1:3] = [10, 11]
#  y gets changed when x is changed
print(y)
# with view, y has a base.
y.base

# %%
import numpy as np
x = np.arange(9).reshape(3, 3)
print('x=',x) # 3 x 3 array
y = x[[1, 2]] # integer array indexing, choose 1 and 2 rows
print('y=',y)
print(y.base is None) # with copy, y has no base.

x[[1, 2]] = [[10, 11, 12], [13, 14, 15]]
print('x=',x)
print('y=',y)
